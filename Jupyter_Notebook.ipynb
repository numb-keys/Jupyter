# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# HARSHIT SINGH
# Data Scientist

# %% [markdown]
# *I want to pursue a career in data science because i want to research on nutrition and it's effects so we can finally solve a plethora of nutrition based diseases*

# %% [markdown]
# ### CODE TO PRINT HELLO

# %%
print ("Hello")

# %% [markdown]
# * Bullet 1
# 1. Numbered
# [This is a link to youtube](https://www.youtube.com/)
